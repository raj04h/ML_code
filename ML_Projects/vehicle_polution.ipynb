# %%
import pandas as pd

# %%
file="D:\Data centr\Exel_data\int data\FuelConsumptionCo2.csv"
fuel=pd.read_csv(file)
fuel
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\himan\AppData\Local\Temp\ipykernel_14180\2302963083.py:1: SyntaxWarning: invalid escape sequence '\D'
#   file="D:\Data centr\Exel_data\int data\FuelConsumptionCo2.csv"
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# ...

# %%
print(fuel.head())
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
print(fuel.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
fuel.describe().T
# Out:
#                            count         mean        std     min      25%  \
# MODELYEAR                 1067.0  2014.000000   0.000000  2014.0  2014.00
# ENGINESIZE                1067.0     3.346298   1.415895     1.0     2.00
# CYLINDERS                 1067.0     5.794752   1.797447     3.0     4.00
# FUELCONSUMPTION_CITY      1067.0    13.296532   4.101253     4.6    10.25
# FUELCONSUMPTION_HWY       1067.0     9.474602   2.794510     4.9     7.50
# FUELCONSUMPTION_COMB      1067.0    11.580881   3.485595     4.7     9.00
# FUELCONSUMPTION_COMB_MPG  1067.0    26.441425   7.468702    11.0    21.00
# CO2EMISSIONS              1067.0   256.228679  63.372304   108.0   207.00
#
#                              50%      75%     max
# MODELYEAR                 2014.0  2014.00  2014.0
# ENGINESIZE                   3.4     4.30     8.4
# CYLINDERS                    6.0     8.00    12.0
# FUELCONSUMPTION_CITY        12.6    15.55    30.2
# ...

# %%
fuel.isnull().sum()
# Out:
# MODELYEAR                   0
# MAKE                        0
# MODEL                       0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %%
import matplotlib.pyplot as pyplt

# %%
pyplt.hist(fuel['TRANSMISSION'],bins=10,color='pink',edgecolor='black')
pyplt.title("Transmission frequency")
pyplt.xlabel("Transmission")
pyplt.ylabel("Frequency")
pyplt.show()

# %%
fuel.hist(figsize=(10,5),bins=10,color='yellow',edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'MODELYEAR'}>,
#         <Axes: title={'center': 'ENGINESIZE'}>,
#         <Axes: title={'center': 'CYLINDERS'}>],
#        [<Axes: title={'center': 'FUELCONSUMPTION_CITY'}>,
#         <Axes: title={'center': 'FUELCONSUMPTION_HWY'}>,
#         <Axes: title={'center': 'FUELCONSUMPTION_COMB'}>],
#        [<Axes: title={'center': 'FUELCONSUMPTION_COMB_MPG'}>,
#         <Axes: title={'center': 'CO2EMISSIONS'}>, <Axes: >]], dtype=object)

# %%
pyplt.scatter(fuel['FUELTYPE'],fuel['TRANSMISSION'],color='green')
pyplt.title("scatter:FuelType vs Transmission")
pyplt.xlabel("FUELTYPE")
pyplt.ylabel("TRANSMISSION")
pyplt.show()

# %%
import seaborn as sb

# %%
sb.displot(fuel,kde=True)
pyplt.title("Fuel Type vs Transmission")
pyplt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
fuel_encoded=fuel.copy()
le=LabelEncoder()
for col in ["MODELYEAR","MAKE","MODEL","VEHICLECLASS","ENGINESIZE","CYLINDERS","TRANSMISSION","FUELTYPE","FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB","FUELCONSUMPTION_COMB_MPG","CO2EMISSIONS"]:
    fuel_encoded[col]=le.fit_transform(fuel_encoded[col])
corr_matrix=fuel_encoded.corr()
print(corr_matrix)
# Out:
#                           MODELYEAR      MAKE     MODEL  VEHICLECLASS  \
# MODELYEAR                       NaN       NaN       NaN           NaN
# MAKE                            NaN  1.000000  0.039068      0.005853
# MODEL                           NaN  0.039068  1.000000      0.244648
# VEHICLECLASS                    NaN  0.005853  0.244648      1.000000
# ENGINESIZE                      NaN -0.161973  0.090514      0.229452
# CYLINDERS                       NaN -0.201508  0.062933      0.212803
# TRANSMISSION                    NaN  0.193264 -0.002004     -0.172934
# FUELTYPE                        NaN  0.015051 -0.051902     -0.083893
# FUELCONSUMPTION_CITY            NaN -0.247657  0.151651      0.341202
# FUELCONSUMPTION_HWY             NaN -0.172793  0.193364      0.426648
# FUELCONSUMPTION_COMB            NaN -0.222687  0.168141      0.375741
# FUELCONSUMPTION_COMB_MPG        NaN  0.225853 -0.150381     -0.355430
# ...

# %%
sb.heatmap(fuel_encoded)
# Out:
# <Axes: >

# %%
pyplt.figure(figsize=(8,8))
sb.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f',linewidths=0.5,linecolor='white')
pyplt.title("correlation heatmap")
pyplt.show()

# %%
sb.pairplot(fuel_encoded,hue="CO2EMISSIONS")

# %%
fuel["CYLINDERS"].fillna(fuel["CYLINDERS"].mean(),inplace=True)
fuel["TRANSMISSION"].fillna(fuel["TRANSMISSION"].mode()[0],inplace=True)
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_14180\3114573150.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fuel["CYLINDERS"].fillna(fuel["CYLINDERS"].mean(),inplace=True)
# C:\Users\himan\AppData\Local\Temp\ipykernel_14180\3114573150.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
print(fuel.head())
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
x=fuel_encoded.drop("FUELTYPE",axis=1)
y=fuel_encoded["FUELTYPE"]

# %%
model=DecisionTreeClassifier()
model.fit(x,y)

feature_import=pd.DataFrame({"Feature": x.columns,"Importance":model.feature_importances_})
feature_import=feature_import.sort_values(by="Importance",ascending=False)
print(feature_import)
# Out:
#                      Feature  Importance
# 1                       MAKE    0.364781
# 7       FUELCONSUMPTION_CITY    0.123369
# 4                 ENGINESIZE    0.103944
# 11              CO2EMISSIONS    0.090036
# 5                  CYLINDERS    0.059645
# 8        FUELCONSUMPTION_HWY    0.059041
# 6               TRANSMISSION    0.052314
# 10  FUELCONSUMPTION_COMB_MPG    0.042632
# 9       FUELCONSUMPTION_COMB    0.042478
# 2                      MODEL    0.035610
# 3               VEHICLECLASS    0.026149
# 0                  MODELYEAR    0.000000

# %%
pyplt.figure(figsize=(10,6))
sb.barplot(x="Importance",y="Feature",data=feature_import)
pyplt.title("Feature Importance")
pyplt.show()

# %%
top_feature=feature_import["Feature"].head(5)
x_selected=x[top_feature]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=30)

# %%
x_test
# Out:
#       MODELYEAR  MAKE  MODEL  VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 879           0    29     66             3          19          3
# 10            0     0    591             0           9          1
# 387           0    11    270             6          27          4
# 1040          0    37    344             0           7          1
# 390           0    11    270             6          27          4
# ...         ...   ...    ...           ...         ...        ...
# 948           0    35    333             0           7          1
# 516           0    14    547             2           9          1
# 117           0     4     94             1          23          4
# 962           0    35    647            11           7          1
# 935           0    32    661             9           9          1
#
#       TRANSMISSION  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 879              8                    63                   36
# ...

# %%
x_train
# Out:
#      MODELYEAR  MAKE  MODEL  VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 165          0     6    196             2          17          3
# 396          0    11    274             0           5          1
# 110          0     4     57             1          23          4
# 766          0    25    402            12          31          4
# 140          0     5    237            12          17          3
# ..         ...   ...    ...           ...         ...        ...
# 898          0    29    135            13          11          3
# 919          0    30      6             6          17          3
# 500          0    13    437            11          16          3
# 941          0    34    610            13          44          5
# 421          0    11    406            10          18          3
#
#      TRANSMISSION  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 165            13                    68                   31
# ...

# %%
y_test
# Out:
# 879     3
# 10      3
# 387     2
# 1040    0
# 390     1
#        ..
# 948     2
# 516     2
# 117     3
# 962     2
# 935     2
# Name: FUELTYPE, Length: 267, dtype: int64

# %%
y_train
# Out:
# 165    2
# 396    2
# 110    3
# 766    3
# 140    2
#       ..
# 898    3
# 919    2
# 500    2
# 941    3
# 421    2
# Name: FUELTYPE, Length: 800, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, mean_squared_error,precision_score,recall_score,f1_score,roc_auc_score,roc_curve,auc

from sklearn.preprocessing import label_binarize

# %%
clf=RandomForestClassifier()
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
precission=precision_score(y_test,y_pred,average="weighted")
recall=recall_score(y_test,y_pred,average="weighted")
f1=f1_score(y_test,y_pred,average="weighted")

# %%
y_test_bin = label_binarize(y_test, classes=[0, 1, 2, 3, 4])  
y_prob = clf.predict_proba(x_test)
roc_auc = roc_auc_score(y_test_bin, y_prob, multi_class='ovr')

# %%
print(f"Accuracy: {accuracy}")
print(f"Precision: {precission}")
print(f"Recall: {recall}")
print(f"F1-Score: {f1}")
print(f"ROC-AUC Score: {roc_auc}")
# Out:
# Accuracy: 0.9176029962546817
# Precision: 0.919061100095469
# Recall: 0.9176029962546817
# F1-Score: 0.9171424020503465
# ROC-AUC Score: 0.9877558403079271

# %%
print("y_test_bin shape:", y_test_bin.shape)
print("y_prob shape:", y_prob.shape)
# Out:
# y_test_bin shape: (267, 5)
# y_prob shape: (267, 4)

# %%
num_classes = min(y_test_bin.shape[1], y_prob.shape[1])
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_prob[:, i])
    roc_auc_value[i] = auc(fpr[i], tpr[i])

# %%
# Assuming y_test_bin and y_prob have been defined and contain the correct shapes.
fpr = {}
tpr = {}
roc_auc_value = {}

# %%
# Calculate ROC curve and AUC for each class
num_classes = min(y_test_bin.shape[1], y_prob.shape[1])
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_prob[:, i])
    roc_auc_value[i] = auc(fpr[i], tpr[i])

# %%
# Plot ROC curves
pyplt.figure(figsize=(10, 8))
for i in range(num_classes):
    pyplt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc_value[i]:.2f})')

# Plotting the diagonal line
pyplt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')

# Adding labels and legend
pyplt.xlabel('False Positive Rate')
pyplt.ylabel('True Positive Rate')
pyplt.title('Receiver Operating Characteristic (ROC) Curve')
pyplt.legend(loc='lower right')
pyplt.grid()
pyplt.show()
